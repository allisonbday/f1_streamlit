# %%
import pandas as pd
import numpy as np

# %%
results_2021 = pd.read_csv(r'../data/results/results_2021.csv')
results_2021
# Out:
#      DriverNumber BroadcastName Abbreviation        DriverId  \
# 0              44    L HAMILTON          HAM        hamilton
# 1              33  M VERSTAPPEN          VER  max_verstappen
# 2              77      V BOTTAS          BOT          bottas
# 3               4      L NORRIS          NOR          norris
# 4              11       S PEREZ          PER           perez
# ..            ...           ...          ...             ...
# 495             6      N LATIFI          LAT          latifi
# 496            99  A GIOVINAZZI          GIO      giovinazzi
# 497            63     G RUSSELL          RUS         russell
# 498             7   K RAIKKONEN          RAI       raikkonen
# 499             9           NaN          MAZ         mazepin
#
#               TeamName TeamColor    TeamId FirstName    LastName  \
# 0             Mercedes    00D2BE  mercedes     Lewis    Hamilton
# 1      Red Bull Racing    0600EF  red_bull       Max  Verstappen
# ...

# %%
laps_2022 = pd.read_csv(r'../data/lap_times/lap_times_2022.csv')
laps_2022
# Out:
#                          Time Driver  DriverNumber                 LapTime  \
# 0      0 days 01:04:15.422000    VER             1  0 days 00:01:40.236000
# 1      0 days 01:05:53.302000    VER             1  0 days 00:01:37.880000
# 2      0 days 01:07:31.659000    VER             1  0 days 00:01:38.357000
# 3      0 days 01:09:10.225000    VER             1  0 days 00:01:38.566000
# 4      0 days 01:10:49.102000    VER             1  0 days 00:01:38.877000
# ...                       ...    ...           ...                     ...
# 24877  0 days 01:37:58.468000    ALO            14  0 days 00:01:31.819000
# 24878  0 days 01:39:29.047000    ALO            14  0 days 00:01:30.579000
# 24879  0 days 01:41:00.112000    ALO            14  0 days 00:01:31.065000
# 24880  0 days 01:42:30.800000    ALO            14  0 days 00:01:30.688000
# 24881  0 days 01:44:03.978000    ALO            14  0 days 00:01:33.178000
#
#        LapNumber  Stint PitOutTime               PitInTime  \
# ...
